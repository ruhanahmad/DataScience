# %%
import plotly.express as px

# %%
nz = px.data.gapminder().query("country == 'New Zealand'")

# %%
nz
# Out:
#           country continent  year  lifeExp      pop    gdpPercap iso_alpha  \
# 1092  New Zealand   Oceania  1952   69.390  1994794  10556.57566       NZL
# 1093  New Zealand   Oceania  1957   70.260  2229407  12247.39532       NZL
# 1094  New Zealand   Oceania  1962   71.240  2488550  13175.67800       NZL
# 1095  New Zealand   Oceania  1967   71.520  2728150  14463.91893       NZL
# 1096  New Zealand   Oceania  1972   71.890  2929100  16046.03728       NZL
# 1097  New Zealand   Oceania  1977   72.220  3164900  16233.71770       NZL
# 1098  New Zealand   Oceania  1982   73.840  3210650  17632.41040       NZL
# 1099  New Zealand   Oceania  1987   74.320  3317166  19007.19129       NZL
# 1100  New Zealand   Oceania  1992   76.330  3437674  18363.32494       NZL
# 1101  New Zealand   Oceania  1997   77.550  3676187  21050.41377       NZL
# 1102  New Zealand   Oceania  2002   79.110  3908037  23189.80135       NZL
# ...

# %%
##
fig = px.bar(nz,x="year",y="pop")

# %%
fig

# %%
fig.layout
# Out:
# Layout({
#     'barmode': 'relative',
#     'legend': {'tracegroupgap': 0},
#     'margin': {'t': 60},
#     'template': '...',
#     'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'year'}},
#     'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'pop'}}
# })

# %%
import plotly.graph_objects as go
iris = px.data.iris()
figtwo = go.Figure(data=go.Scatter(x=iris['sepal_width'],y=iris['sepal_length'],mode="markers"))
figtwo

# %%
iris = px.data.iris()
fig = px.scatter(iris, x="sepal_width" , y = "sepal_length", color ="species",title="Sepal lenght vs sepal width")
fig

# %%
config = {'displaylogo':False}
fig.show(config=config)

# %%
fig.write_image("iris-viz.png")

# %%
pip install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
chartss = px.data.gapminder().query("continent == 'Oceania'")

# %%
chartss
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 60      Australia   Oceania  1952   69.120   8691212  10039.59564       AUS
# 61      Australia   Oceania  1957   70.330   9712569  10949.64959       AUS
# 62      Australia   Oceania  1962   70.930  10794968  12217.22686       AUS
# 63      Australia   Oceania  1967   71.100  11872264  14526.12465       AUS
# 64      Australia   Oceania  1972   71.930  13177000  16788.62948       AUS
# 65      Australia   Oceania  1977   73.490  14074100  18334.19751       AUS
# 66      Australia   Oceania  1982   74.740  15184200  19477.00928       AUS
# 67      Australia   Oceania  1987   76.320  16257249  21888.88903       AUS
# 68      Australia   Oceania  1992   77.560  17481977  23424.76683       AUS
# 69      Australia   Oceania  1997   78.830  18565243  26997.93657       AUS
# 70      Australia   Oceania  2002   80.370  19546792  30687.75473       AUS
# ...

# %%
fig = px.line(chartss,x="year",y ="lifeExp")
fig

# %%
fig.update_layout(legend=dict(yanchor="top",y=0.95,xanchor = "left",x=0.01),title = "Average  Life Expitancy")

# %%
fig.update_traces(mode = "markers")

# %%
figbar = px.bar(chartss,x="year",y ="lifeExp")
figbar

# %%
figbar = px.bar(chartss,x="year",y ="lifeExp",barmode="group",color="country",category_orders={"country":["New Zealand","Australia",]})
figbar
figbar.show()

# %%
dfthree = px.data.gapminder().query("year == '2005'")
dfthree.head()
# Out:
# Empty DataFrame
# Columns: [country, continent, year, lifeExp, pop, gdpPercap, iso_alpha, iso_num]
# Index: []

# %%
fig =px.scatter(chartss,x="year",y ="lifeExp",color="country",size ="pop",labels={"lefExp":"Life Expentanc",'gdpPercap':"GDP per captcha"})
fig
fig.show()

# %%
fig = px.histogram(chartss,x="continent",y="year")

# %%
fig

# %%
fig = px.line(chartss,x="year",y="lifeExp",color ="country")
fig

# %%
fig.update_layout(legend=dict(yanchor="top",y=0.95,xanchor="left",x=0.01),title= "AVerage of country")
fig.update_traces(mode = "markers")

# %%
fig = px.histogram(chartss,x="year",y="lifeExp",color ="country")
fig

# %%
import plotly.figure_factory as ff

# %%
df = px.data.tips()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig =px.histogram(df,x="total_bill",color="time",y="tip",histfunc="avg")
fig

# %%
dinner_tip = df[df['time'] == "Dinner"]["tip"]
lunch_tip  = df[df['time'] == "Lunch"]["tip"]

group_labels = ['dinner','lunch']
hist_data = [dinner_tip,lunch_tip]

# %%
fig =ff.create_distplot(hist_data,group_labels,)
fig.show()

# %%
iris =px.data.iris()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig = px.scatter_matrix(iris,dimensions=["sepal_length","sepal_width","petal_length","petal_width"],color="species")

# %%
fig.show()

# %%
dftwo= px.data.gapminder()

# %%
fig = px.scatter_3d(dftwo[dftwo['continent']=="Europe"],x="lifeExp",y="year",z="gdpPercap",color="country")
fig.show()

# %%
fig = px.line_3d(dftwo[dftwo['continent']=="Europe"],x="lifeExp",y="year",z="gdpPercap",color="country")
fig.show()

# %%
import plotly.graph_objects as go
fig =go.Figure(data=(go.Surface(z=dftwo.values,colorscale="Earth")))
fig

# %%
fig = px.scatter_geo(dftwo,locations="iso_alpha",color="continent",size="pop",text="country")
fig.show()

# %%
fig = px.choropleth(dftwo,locations="iso_alpha",color="lifeExp",color_continuous_scale="Viridis")
fig.show()

# %%
pip install geopandas
# Out:
# ...
#
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# ...
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install geopandas
# Out:
# ...
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# ...
#   Using cached pyproj-3.4.0-cp310-cp310-win_amd64.whl (4.8 MB)
# ...
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import geopandas as gdp
import pandas as pd
peaks = pd.read_csv("kashti.csv")
peaks = gpd.GeoDataFrame(peaks,geometry = gpd.points_from_xy(peaks.lon,peaks.lat))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\New folder\pythonkachilla\DataScience\pythonplotly\visulisation.ipynb Cell 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/New%20folder/pythonkachilla/DataScience/pythonplotly/visulisation.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> import geopandas as gdp
#       <a href='vscode-notebook-cell:/d%3A/New%20folder/pythonkachilla/DataScience/pythonplotly/visulisation.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/New%20folder/pythonkachilla/DataScience/pythonplotly/visulisation.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a> peaks = pd.read_csv("kashti.csv")
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import plotly.express as px
import pandas as pd

# %%
earth = pd.DataFrame({'labels':['Earth','Land','Water','Agricultural Land','Non-Agricultural Land','Saline','Freshwater'],
                      'parents':['','Earth','Earth','Land','Land','Water','Water'],
                      'values':[1,.29,.71,.10933,.18067,.68515,.02485]})

earth
# Out:
#                   labels parents   values
# 0                  Earth          1.00000
# 1                   Land   Earth  0.29000
# 2                  Water   Earth  0.71000
# 3      Agricultural Land    Land  0.10933
# 4  Non-Agricultural Land    Land  0.18067
# 5                 Saline   Water  0.68515
# 6             Freshwater   Water  0.02485

# %%
fig = px.sunburst(earth,names ='labels',parents='parents',values='values',branchvalues='total')

# %%
fig.show()

# %%
fig = px.sunburst(earth,
                  names='labels',
                  parents='parents',
                  values='values',
                  branchvalues='total')

fig.show()

# %%
df = px.data.gapminder().query("year == 2007")
df.head(3)
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338       AFG
# 23      Albania    Europe  2007   76.423   3600523  5937.029526       ALB
# 35      Algeria    Africa  2007   72.301  33333216  6223.367465       DZA
#
#     iso_num
# 11        4
# 23        8
# 35       12

# %%
df = px.data.gapminder().query('year==2007')
fig = px.sunburst(df, 
                  path=['continent', 'country'],
                  color='lifeExp', 
                  values='pop')
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
salmon = pd.read_csv('salmon-survival.csv')

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(
      label = ['Chinook Released','Coho Released','Sockeye Released','Re-Captured','Not Re-Captured','Returned','Not Re-Captured',],
    ),
    link = dict(
      source = salmon['source'],
      target = salmon['target'],
      value = salmon['value']
  ))])

# %%
  fig.show()

# %%
import plotly.express as px
df = px.data.gapminder()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
fig = px.scatter_3d(df[df['continent'] == 'Europe'],
       x = 'lifeExp',
       y = 'pop',
       z = 'gdpPercap',
       color = "country",
       animation_frame="year",
       animation_group="country",

 
)
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Sunburst( 
    labels = ['Earth','Land','Water','Agricultural Land','Non-Agricultural Land','Saline','Freshwater'], 
    parents = ['','Earth','Earth','Land','Land','Water','Water'], 
    values = [1,.29,.71,.10933,.18067,.68515,.02485], 
    branchvalues='total'
)) 
fig

# %%
fig.update_layout(
    updatemenus=[
        go.layout.Updatemenu(
            type="buttons",
            buttons=list([      
                dict(
                    args=[{"marker":""}],
                    label="Original Color",
                    method="update"),
                dict(
                    args=[{"marker.colors": [[1,.29,.71,.10933,.18067,.68515,.02485]]
                           ,"marker.showscale":True
                           ,"marker.colorscale":"Viridis"}],
                    label="Color by % of Earth",
                    method="update")
                ]))])

# %%
df = px.data.gapminder().query("year == 2007")
fig = px.scatter(df, x="lifeExp", y="gdpPercap", color="country", facet_col="continent",facet_col_wrap=2)
fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = px.data.gapminder().query("continent=='Oceania'")

# %%
fig = make_subplots(
    rows=1, cols=2,
    specs=[[{"type": "xy"}, {"type": "xy"}]])

# %%
fig.add_trace(go.Bar(x=df[(df['year']==2007) & (df['country']=='New Zealand')]['country'],
                     y=df[(df['year']==2007) & (df['country']=='New Zealand')]['pop']),
              row=1, col=2)
fig.add_trace(go.Bar(x=df[(df['year']==2007) & (df['country']=='Australia')]['country'],
                     y=df[(df['year']==2007) & (df['country']=='Australia')]['pop']),
              row=1, col=2)

fig.add_trace(go.Scatter(x=df[df['country']=='New Zealand']['year'], 
                         y=df[df['country']=='New Zealand']['pop'],
                         mode='lines',
                         name='lines'),
              row=1, col=1)
fig.add_trace(go.Scatter(x=df[df['country']=='Australia']['year'], 
                         y=df[df['country']=='Australia']['pop'],
                         mode='lines',
                         name='lines'),
              row=1, col=1)

fig.update_layout(title='Population of Oceania')

# %%
pip install jupyter_dash
# Out:
# ...
#
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# ...
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# ...
#   Using cached dash-2.6.1-py3-none-any.whl (9.9 MB)
# ...
#   Using cached Flask-2.2.2-py3-none-any.whl (101 kB)
# ...
#   Using cached Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# ...
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# ...
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# ...
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# ...
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# ...
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# ...
#      ------------------------------------ 383.3/383.3 kB 238.7 kB/s eta 0:00:00
# ...

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Out:
# C:\Users\Biscode\AppData\Local\Temp\ipykernel_18248\421913960.py:3: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#
# C:\Users\Biscode\AppData\Local\Temp\ipykernel_18248\421913960.py:4: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
df = px.data.tips()

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")]
)
def update_figure(colorscale):
    return px.scatter(
        df, x="total_bill", y="tip", color="size",
        color_continuous_scale=colorscale,
        render_mode="webgl", title="Tips"
    )

# %%
app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import chart_studio
import chart_studio.plotly as py

# %%
chart_studio.tools.set_credentials_file(username=username,api_key=api_key)
