# %% [markdown]
# ### Varoius method to Normalise Data

# %% [markdown]
# ### Resources and links from where i get the info
# #### https://www.malicksarr.com/data-standardization-with-python/

# %% [markdown]
# #### https://www.malicksarr.com/how-to-normalize-your-data-with-python/

# %% [markdown]
# ### Min-Max Scaler

# %%
#### Min Max Scaler
from sklearn import preprocessing
import pandas as pd
import numpy as np
Insurance_Data = pd.read_csv('mldata.csv')

# %%
gendermale = Insurance_Data['gender'].replace("Male",1,inplace=True)
genderFemale = Insurance_Data['gender'].replace("Female",0,inplace=True)

# %%
Insurance_Data
# Out:
#      age   height  weight  gender likeness
# 0     27  170.688    76.0       1  Biryani
# 1     41  165.000    70.0       1  Biryani
# 2     29  171.000    80.0       1  Biryani
# 3     27  173.000   102.0       1  Biryani
# 4     29  164.000    67.0       1  Biryani
# ..   ...      ...     ...     ...      ...
# 240   31  160.000    60.0       1   Pakora
# 241   26  172.000    70.0       1  Biryani
# 242   40  178.000    80.0       1  Biryani
# 243   25    5.700    65.0       1  Biryani
# 244   33  157.000    56.0       0   Samosa
#
# [245 rows x 5 columns]

# %%
housing['gender'] = housing['gender'].replace("Male",1)
housing['gender'] = housing['gender'].replace("Female",0)

# %%
housing['gender']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 240    1
# 241    1
# 242    1
# 243    1
# 244    0
# Name: gender, Length: 245, dtype: int64

# %%
housing['likeness'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
housing['likeness'] = housing['likeness'].replace("Biryani",0)
housing['likeness'] = housing['likeness'].replace("Pakora",1)
housing['likeness'] = housing['likeness'].replace("Samosa",2)

# %%
housing['likeness']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 240    1
# 241    0
# 242    0
# 243    0
# 244    2
# Name: likeness, Length: 245, dtype: int64

# %%
scaler = preprocessing.MinMaxScaler(feature_range=(0, 2))
names = housing.columns
d = scaler.fit_transform(housing)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df.head()
# Out:
#     age    height    weight  gender  likeness
# 0  0.36  0.594714  0.809249     2.0       0.0
# 1  0.92  0.574696  0.739884     2.0       0.0
# 2  0.44  0.595812  0.855491     2.0       0.0
# 3  0.36  0.602851  1.109827     2.0       0.0
# 4  0.44  0.571177  0.705202     2.0       0.0

# %% [markdown]
# ### Standardization

# %% [markdown]
# ### Why you standardize data/

# %% [markdown]
# #### The idea behind it is simple. Let say we use age and salary as variables for our model. The range of values for the age would vary between 18-60, while the range of values for salary could vary between $20k-$250k. So these huge differences in values could affect the model performances of value-sensitive models (PCA, KNN, SVM). Another perk of standardizing is that it may make your model run slightly faster since you are using smaller values than the original.

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
data = np.array([[-1000.5], 
              [-82.1], 
              [0], 
              [100], 
              [900.9]])


# initialize the scaler
scaler = StandardScaler()

# Apply the transormation
standardized = scaler.fit_transform(data)

# %%
standardized
# Out:
# array([[-1.62764418],
#        [-0.10875659],
#        [ 0.02702376],
#        [ 0.19240786],
#        [ 1.51696914]])

# %% [markdown]
# ## NP LOG Transformation Method

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = stats.gamma.rvs(1, size=5000)+5
sns.set_style("whitegrid")

ax = sns.displot(x, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Original distribution', size = 20)

x_norm = np.log(x)

ax = sns.displot(x_norm, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Distribution after Log transfomation', size = 20)
# Out:
# Text(0.5, 0.98, 'Distribution after Log transfomation')

# %% [markdown]
# ### SQRT method

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = stats.gamma.rvs(1, size=5000)+5
sns.set_style("whitegrid")

ax = sns.displot(x, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Original distribution', size = 20)

x_norm = np.sqrt(x)

ax = sns.displot(x_norm, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Distribution after Squareroot transfomation', size = 20)
# Out:
# Text(0.5, 0.98, 'Distribution after Squareroot transfomation')

# %% [markdown]
# ### 4. Reciprocal Transformation
# In this method, we will simply replace each value with its inverse using (1/x). This method has little effect on the shape of the distribution compared to the other methods and can only be used for non-zero values.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = stats.gamma.rvs(1, size=5000)+5
sns.set_style("whitegrid")

ax = sns.displot(x, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Original distribution', size = 20)

x_norm = 1/x

ax = sns.displot(x_norm, kind = "kde",color = "#e64e4e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Distribution after Reciprocal transfomation', size = 20)
# Out:
# Text(0.5, 0.98, 'Distribution after Reciprocal transfomation')
