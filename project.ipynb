# %% [markdown]
# # This is project for Analysis

# %% [markdown]
# ## importing data from Fost.Org

# %%
import numpy as np 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("fostproduction.csv")
data
# Out:
#     Domain Code                        Domain  Area Code      Area  \
# 0           QCL  Crops and livestock products        165  Pakistan
# 1           QCL  Crops and livestock products        165  Pakistan
# 2           QCL  Crops and livestock products        165  Pakistan
# 3           QCL  Crops and livestock products        165  Pakistan
# 4           QCL  Crops and livestock products        165  Pakistan
# ..          ...                           ...        ...       ...
# 175         QCL  Crops and livestock products        165  Pakistan
# 176         QCL  Crops and livestock products        165  Pakistan
# 177         QCL  Crops and livestock products        165  Pakistan
# 178         QCL  Crops and livestock products        165  Pakistan
# 179         QCL  Crops and livestock products        165  Pakistan
#
#      Element Code         Element  Item Code            Item  Year Code  Year  \
# 0            5312  Area harvested       1717  Cereals, Total       1961  1961
# 1            5419           Yield       1717  Cereals, Total       1961  1961
# 2            5510      Production       1717  Cereals, Total       1961  1961
# 3            5312  Area harvested       1717  Cereals, Total       1962  1962
# 4            5419           Yield       1717  Cereals, Total       1962  1962
# ..            ...             ...        ...             ...        ...   ...
# 175          5419           Yield       1717  Cereals, Total       2019  2019
# 176          5510      Production       1717  Cereals, Total       2019  2019
# 177          5312  Area harvested       1717  Cereals, Total       2020  2020
# 178          5419           Yield       1717  Cereals, Total       2020  2020
# 179          5510      Production       1717  Cereals, Total       2020  2020
#
#        Unit     Value Flag                                   Flag Description
# 0        ha   7858558    A  Aggregate, may include official, semi-official...
# 1     hg/ha      8564   Fc                                    Calculated data
# 2    tonnes   6729680    A  Aggregate, may include official, semi-official...
# 3        ha   8090856    A  Aggregate, may include official, semi-official...
# 4     hg/ha      8580   Fc                                    Calculated data
# ..      ...       ...  ...                                                ...
# 175   hg/ha     28938   Fc                                    Calculated data
# 176  tonnes  40205238    A  Aggregate, may include official, semi-official...
# 177      ha  14082566    A  Aggregate, may include official, semi-official...
# 178   hg/ha     30208   Fc                                    Calculated data
# 179  tonnes  42540915    A  Aggregate, may include official, semi-official...
#
# [180 rows x 14 columns]

# %% [markdown]
# # dropping

# %%
data.drop(["Domain Code"],axis=1)
# Out:
#                            Domain  Area Code      Area  Element Code  \
# 0    Crops and livestock products        165  Pakistan          5312
# 1    Crops and livestock products        165  Pakistan          5419
# 2    Crops and livestock products        165  Pakistan          5510
# 3    Crops and livestock products        165  Pakistan          5312
# 4    Crops and livestock products        165  Pakistan          5419
# ..                            ...        ...       ...           ...
# 175  Crops and livestock products        165  Pakistan          5419
# 176  Crops and livestock products        165  Pakistan          5510
# 177  Crops and livestock products        165  Pakistan          5312
# 178  Crops and livestock products        165  Pakistan          5419
# 179  Crops and livestock products        165  Pakistan          5510
#
#             Element  Item Code            Item  Year Code  Year    Unit  \
# 0    Area harvested       1717  Cereals, Total       1961  1961      ha
# 1             Yield       1717  Cereals, Total       1961  1961   hg/ha
# 2        Production       1717  Cereals, Total       1961  1961  tonnes
# 3    Area harvested       1717  Cereals, Total       1962  1962      ha
# 4             Yield       1717  Cereals, Total       1962  1962   hg/ha
# ..              ...        ...             ...        ...   ...     ...
# 175           Yield       1717  Cereals, Total       2019  2019   hg/ha
# 176      Production       1717  Cereals, Total       2019  2019  tonnes
# 177  Area harvested       1717  Cereals, Total       2020  2020      ha
# 178           Yield       1717  Cereals, Total       2020  2020   hg/ha
# 179      Production       1717  Cereals, Total       2020  2020  tonnes
#
#         Value Flag                                   Flag Description
# 0     7858558    A  Aggregate, may include official, semi-official...
# 1        8564   Fc                                    Calculated data
# 2     6729680    A  Aggregate, may include official, semi-official...
# 3     8090856    A  Aggregate, may include official, semi-official...
# 4        8580   Fc                                    Calculated data
# ..        ...  ...                                                ...
# 175     28938   Fc                                    Calculated data
# 176  40205238    A  Aggregate, may include official, semi-official...
# 177  14082566    A  Aggregate, may include official, semi-official...
# 178     30208   Fc                                    Calculated data
# 179  42540915    A  Aggregate, may include official, semi-official...
#
# [180 rows x 13 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example planets dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=data,
    x="Year", y="Value",
    hue="Year", 
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
data[data["Year"] > 1962]
# Out:
#     Domain Code                        Domain  Area Code      Area  \
# 6           QCL  Crops and livestock products        165  Pakistan
# 7           QCL  Crops and livestock products        165  Pakistan
# 8           QCL  Crops and livestock products        165  Pakistan
# 9           QCL  Crops and livestock products        165  Pakistan
# 10          QCL  Crops and livestock products        165  Pakistan
# ..          ...                           ...        ...       ...
# 175         QCL  Crops and livestock products        165  Pakistan
# 176         QCL  Crops and livestock products        165  Pakistan
# 177         QCL  Crops and livestock products        165  Pakistan
# 178         QCL  Crops and livestock products        165  Pakistan
# 179         QCL  Crops and livestock products        165  Pakistan
#
#      Element Code         Element  Item Code            Item  Year Code  Year  \
# 6            5312  Area harvested       1717  Cereals, Total       1963  1963
# 7            5419           Yield       1717  Cereals, Total       1963  1963
# 8            5510      Production       1717  Cereals, Total       1963  1963
# 9            5312  Area harvested       1717  Cereals, Total       1964  1964
# 10           5419           Yield       1717  Cereals, Total       1964  1964
# ..            ...             ...        ...             ...        ...   ...
# 175          5419           Yield       1717  Cereals, Total       2019  2019
# 176          5510      Production       1717  Cereals, Total       2019  2019
# 177          5312  Area harvested       1717  Cereals, Total       2020  2020
# 178          5419           Yield       1717  Cereals, Total       2020  2020
# 179          5510      Production       1717  Cereals, Total       2020  2020
#
#        Unit     Value Flag                                   Flag Description
# 6        ha   8212602    A  Aggregate, may include official, semi-official...
# 7     hg/ha      8777   Fc                                    Calculated data
# 8    tonnes   7208300    A  Aggregate, may include official, semi-official...
# 9        ha   8533549    A  Aggregate, may include official, semi-official...
# 10    hg/ha      8865   Fc                                    Calculated data
# ..      ...       ...  ...                                                ...
# 175   hg/ha     28938   Fc                                    Calculated data
# 176  tonnes  40205238    A  Aggregate, may include official, semi-official...
# 177      ha  14082566    A  Aggregate, may include official, semi-official...
# 178   hg/ha     30208   Fc                                    Calculated data
# 179  tonnes  42540915    A  Aggregate, may include official, semi-official...
#
# [174 rows x 14 columns]
