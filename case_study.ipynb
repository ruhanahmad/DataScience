# %%
import numpy as np 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti.drop(['fare'],axis = 1)
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked   class    who  \
# 0           0       3    male  22.0      1      0        S   Third    man
# 1           1       1  female  38.0      1      0        C   First  woman
# 2           1       3  female  26.0      0      0        S   Third  woman
# 3           1       1  female  35.0      1      0        S   First  woman
# 4           0       3    male  35.0      0      0        S   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0        S  Second    man
# 887         1       1  female  19.0      0      0        S   First  woman
# 888         0       3  female   NaN      1      2        S   Third  woman
# 889         1       1    male  26.0      0      0        C   First    man
# 890         0       3    male  32.0      0      0        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
kashti.groupby(['sex']).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
kashti.value_counts(['survived'])
# Out:
# survived
# 0           549
# 1           342
# dtype: int64

# %%
kashti[kashti['age'] < 17]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 850         0       3    male   4.0      4      2  31.2750        S   Third
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[kashti['age'] < 17].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.833333     1.0  13.166667  0.333333  1.166667  111.127783
#        Second  1.000000     2.0   6.600000  0.700000  1.300000   29.240000
#        Third   0.545455     3.0   7.909091  1.545455  1.060606   19.184724
# male   First   1.000000     1.0   5.306667  0.666667  2.000000  117.802767
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.270270     3.0   8.822162  2.351351  1.135135   25.161151
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.166667
#        Second    0.000000  0.000000
#        Third     0.000000  0.212121
# male   First     0.000000  0.000000
#        Second    0.181818  0.181818
#        Third     0.243243  0.162162

# %%
fost = pd.read_csv("fost.csv")
fost
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
fost.mean()
# Out:
# C:\Users\Biscode\AppData\Local\Temp\ipykernel_13684\818514297.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fost.mean()
# Area Code       1.650000e+02
# Element Code    6.123000e+03
# Item Code       2.101300e+04
# Year Code       2.009701e+07
# Value           6.153889e+01
# Note                     NaN
# dtype: float64

# %%
fost.head()
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6123   Value      21013
# 1          6123   Value      21013
# 2          6123   Value      21013
# 3          6123   Value      21013
# 4          6123   Value      21013
#
#                                                 Item  Year Code       Year  \
# 0  Average protein supply (g/cap/day) (3-year ave...   19992001  1999-2001
# 1  Average protein supply (g/cap/day) (3-year ave...   20002002  2000-2002
# 2  Average protein supply (g/cap/day) (3-year ave...   20012003  2001-2003
# ...

# %%
group = fost.groupby("Area").mean()
group
# Out:
#           Area Code  Element Code  Item Code   Year Code      Value  Note
# Area
# Pakistan      165.0        6123.0    21013.0  20097011.5  61.538889   NaN

# %%
fost.drop(["Note"],axis = 1)
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
fost.value_counts(['Year'])
# Out:
# Year
# 1999-2001    1
# 2000-2002    1
# 2019-2021    1
# 2018-2020    1
# 2017-2019    1
# 2016-2018    1
# 2015-2017    1
# 2014-2016    1
# 2013-2015    1
# 2012-2014    1
# 2011-2013    1
# 2010-2012    1
# 2009-2011    1
# 2008-2010    1
# 2007-2009    1
# 2006-2008    1
# 2005-2007    1
# 2004-2006    1
# 2003-2005    1
# 2002-2004    1
# 2001-2003    1
# 2020-2022    1
# dtype: int64
